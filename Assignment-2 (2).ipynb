# %% [markdown]
# square number

# %%
a=36
print(a**0.5)
print("sum")
# Out:
# 6.0
# sum

# %% [markdown]
# tuple

# %%
person=("mcp","21","kle")
print("name:",person[0])
print("age:",person[1])
print("college:",person[2])
# Out:
# name: mcp
# age: 21
# college: kle

# %% [markdown]
# tripple

# %% [markdown]
# class data types

# %%
name1="mcp"
name2="2.5"
print(type(name1))
print(type(name2))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# lists

# %%
lis=['a','b','kle','bvb']
lis[0]
# Out:
# 'a'
