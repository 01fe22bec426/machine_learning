# %% [markdown]
# square number

# %%
a=36
print(a**0.5)
print("sum")
# Out:
# 6.0
# sum

# %% [markdown]
# dictionary

# %%
Dict1={"stu name":"mcp",
       "usn no":"01fe22bec426"}
print(Dict1)
# Out:
# {'stu name': 'mcp', 'usn no': '01fe22bec426'}

# %% [markdown]
# tuple

# %%
person=("mcp","21","kle")
print("name:",person[0])
print("age:",person[1])
print("college:",person[2])
# Out:
# name: mcp
# age: 21
# college: kle

# %% [markdown]
# tripple

# %% [markdown]
#  data types

# %%
name1="mcp"
name2="2.5"
name3="4"
print(type(name1))
print(type(name2))
print(type(name3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# lists

# %%
lis=['a','b','kle','bvb']
lis[0]
# Out:
# 'a'
